# %% [markdown]
# <a href="https://colab.research.google.com/github/Samenergy/Student-Presentations-Bernoulli-Distribution-Peer-Group-9/blob/main/Python_Code_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
p = 0.6  # Probability of success

# Generate 1000 Bernoulli trials
trials = np.random.binomial(n=1, p=p, size=1000)

# Count occurrences of 0 and 1
unique, counts = np.unique(trials, return_counts=True)
probabilities = counts / sum(counts)

# Plotting
plt.bar(unique, probabilities, tick_label=["Failure (0)", "Success (1)"], color=["blue", "green"])
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.title(f"Bernoulli Distribution (p = {p})")
plt.show()
